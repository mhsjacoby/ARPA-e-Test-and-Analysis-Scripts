# %%
# import os
# import sys
import csv
# import ast
# import json
from datetime import datetime
from datetime import timedelta
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.pyplot import figure
import matplotlib.dates as mdates
plt.rcParams.update({'font.size': 14})

# %%
D = 14

def plot_occ_asPD(occ_csv):
    df = pd.read_csv(occ_csv, delimiter = ',', index_col = 0, header = 0)
    df['datetime_index'] = pd.to_datetime(df.index)         
    df = df.set_index('datetime_index')
    dfs = []
    day1 = df.index[0]
    #for x in range()
    dayn = day1 + timedelta(days = D)
    num_weeks = int(np.ceil(len(df)/(1440*days)))
    dfn = df.loc[df.index < dayn]
#     for i in range(1,num_weeks+1):
#         print(i)
    return dfn

# %%
60*24
# Out:
# 1440

# %%
path = '/Users/maggie/Desktop/HPD_mobile_data/HPD_mobile-H5/H5-Occupancy_df.csv'


new_df = plot_occ_asPD(path)
names = new_df.columns[0:-2]
num_occs = len(names)
for name in names:
    print(name)
    new_df.plot(y=name)
# Out:
# Zahra
# Maggie
# Vahid

# %%
# Out:
# Index(['Zahra', 'Maggie', 'Vahid'], dtype='object')
