# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import medfilt
from scipy.io import loadmat
import os

# %% [markdown]
# # Parameters

# %%
fft_size = 2048
fs = 2e6;
num_avg_window = 25
window_size = 501

# %% [markdown]
# # Load & Reshape data

# %%
def mylistdir(directory):
    filelist = os.listdir(directory)
    return [x for x in filelist if x.endswith('.bin')] 


### Read in binary file ###
def fread(fid, dtype):
    if dtype is np.str:
        dt = np.uint8  # WARNING: assuming 8-bit ASCII for np.str!
    else:
        dt = dtype
        
    data_array = np.fromfile(fid, dt)
    return data_array


def get_time(x):
    ### Reshape data ###
    T = int(len(x)/fft_size);
    data = np.reshape(x, (fft_size,T), order="F")

    ### Get time ###
    total_time = len(x)*(1/fs)
    bin_duration = fft_size*(1/fs)
    time = np.arange(0.0, total_time-(1/fs), bin_duration)
    return T, time, data

# %% [markdown]
# # Compute Averaged Frames

# %%
def compute_avg_frames(T, time, data):
    spectra_avg = np.zeros((fft_size, int(np.floor(T)/num_avg_window)))
    count = 0;

    for i in range(0,T-num_avg_window, num_avg_window):
        spectra_avg[:,count] = np.mean(data[:,i:i+num_avg_window-1],axis=1)
        count += 1

    indices = np.arange(0, len(time)-num_avg_window, num_avg_window)
    time = np.take(time, indices)
    return time, spectra_avg, indices


def abs_sum_fft(spectra_avg, fname):
    [rows, columns] = np.shape(spectra_avg)
    signal = np.zeros(columns)

    for i in range(columns):
        signal[i] = np.sum(np.abs(spectra_avg[:,i]))
        
    print(fname + ' First')
    plt.figure(figsize = (15,5))
    plt.plot(time, signal)
    plt.show()
    
    sig_norm = (signal - np.min(signal))/(np.max(signal)-np.min(signal))
    
    for i in range(len(sig_norm)):
        if sig_norm[i] <= 0:
            sig_norm[i] = sig_norm[i+1]
        
    print(fname + ' second')
    plt.figure(figsize = (15,5))
    plt.plot(time, sig_norm)
    plt.show()
    
    
    
    return sig_norm


def plot_sig(time, sig_norm, fname):
    sig_filt = medfilt(sig_norm, window_size)

    plt.figure(figsize = (15,5))
    plt.plot(time, sig_filt)
    plt.savefig(fname + '.png')
    print(fname + '.png')
    plt.show()
    np.savetxt(fname + '.txt', sig_filt)

# %%
# path = '/Volumes/USRP/2019-10-07_H6/'
# saveP = '/Volumes/USRP/'
# path = '/Users/maggie/Documents/Maggie-Grad-School/HPDmobile/USRP-Related/H1-2019-09-18/raw_data/'
# saveP = '/Users/maggie/Documents/Maggie-Grad-School/HPDmobile/USRP-Related/H1-2019-09-18/'
path = '/Users/maggie/Desktop/2019-10-07_H6/'
saveP = '/Users/maggie/Desktop/Figures/H6'
file_list = mylistdir(path)
print(file_list)
# Out:
# ['microwave1.bin', 'desk_lamp1.bin', 'burner1.bin', 'kitchen1.bin', 'hairdryer_light1.bin', 'bathroom1.bin', 'stove1.bin', 'bed_lamp1.bin', 'tv_lamp1.bin', 'lamp1.bin', 'monitor1.bin', 'upstairs_all_1.bin', 'all_lights.bin', 'test_1.bin', 'stairs_1.bin', 'charger1.bin', 'phone1.bin', 'overhead1.bin', 'hairdryer1.bin', 'tv1.bin', 'charger_upstairs_1.bin', 'hallway1.bin']

# %%
for f in file_list:
    fid = open(os.path.join(path, f), 'rb');
    title = f.split('.bin')[0]
    x = fread(fid, 'single')
    print(type(x))
    
    T, time, DATA = get_time(x)
    time, spec_avg, ind = compute_avg_frames(T, time, DATA)
    signal = abs_sum_fft(spec_avg, title)
    
    save_path = os.path.join(saveP, 'figures')
    if not os.path.isdir(save_path):
        os.makedirs(save_path)
        
    fname = os.path.join(save_path, title)
    plot_sig(time, signal, fname)
# Out:
# microwave1 First
# microwave1 second
# /Users/maggie/Desktop/Figures/H6/figures/microwave1.png
# desk_lamp1 First
# desk_lamp1 second
# /Users/maggie/Desktop/Figures/H6/figures/desk_lamp1.png
# burner1 First
# burner1 second
# /Users/maggie/Desktop/Figures/H6/figures/burner1.png
# kitchen1 First
# kitchen1 second
# /Users/maggie/Desktop/Figures/H6/figures/kitchen1.png
# hairdryer_light1 First
# hairdryer_light1 second
# /Users/maggie/Desktop/Figures/H6/figures/hairdryer_light1.png
# bathroom1 First
# bathroom1 second
# /Users/maggie/Desktop/Figures/H6/figures/bathroom1.png
# stove1 First
# stove1 second
# /Users/maggie/Desktop/Figures/H6/figures/stove1.png
# bed_lamp1 First
# bed_lamp1 second
# /Users/maggie/Desktop/Figures/H6/figures/bed_lamp1.png
# tv_lamp1 First
# tv_lamp1 second
# /Users/maggie/Desktop/Figures/H6/figures/tv_lamp1.png
# lamp1 First
# lamp1 second
# /Users/maggie/Desktop/Figures/H6/figures/lamp1.png
# monitor1 First
# monitor1 second
# /Users/maggie/Desktop/Figures/H6/figures/monitor1.png
# upstairs_all_1 First
# upstairs_all_1 second
# /Users/maggie/Desktop/Figures/H6/figures/upstairs_all_1.png
# all_lights First
# all_lights second
# /Users/maggie/Desktop/Figures/H6/figures/all_lights.png
# test_1 First
# test_1 second
# /Users/maggie/Desktop/Figures/H6/figures/test_1.png
# stairs_1 First
# stairs_1 second
# /Users/maggie/Desktop/Figures/H6/figures/stairs_1.png
# charger1 First
# charger1 second
# /Users/maggie/Desktop/Figures/H6/figures/charger1.png
# phone1 First
# phone1 second
# /Users/maggie/Desktop/Figures/H6/figures/phone1.png
# overhead1 First
# overhead1 second
# /Users/maggie/Desktop/Figures/H6/figures/overhead1.png
# hairdryer1 First
# hairdryer1 second
# /Users/maggie/Desktop/Figures/H6/figures/hairdryer1.png
# tv1 First
# tv1 second
# /Users/maggie/Desktop/Figures/H6/figures/tv1.png
# charger_upstairs_1 First
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-9632177e91e3> in <module>
#       6     T, time, DATA = get_time(x)
#       7     time, spec_avg, ind = compute_avg_frames(T, time, DATA)
# ----> 8     signal = abs_sum_fft(spec_avg, title)
#       9
#      10     save_path = os.path.join(saveP, 'figures')
#
# <ipython-input-22-bece3d7d3327> in abs_sum_fft(spectra_avg, fname)
#      21     print(fname + ' First')
#      22     plt.figure(figsize = (15,5))
# ---> 23     plt.plot(time, signal)
#      24     plt.show()
#      25
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2811     return gca().plot(
#    2812         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2813         is not None else {}), **kwargs)
#    2814
#    2815
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in plot(self, scalex, scaley, *args, **kwargs)
#    1609         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D._alias_map)
#    1610
# -> 1611         for line in self._get_lines(*args, **kwargs):
#    1612             self.add_line(line)
#    1613             lines.append(line)
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _grab_next_args(self, *args, **kwargs)
#     391                 this += args[0],
#     392                 args = args[1:]
# --> 393             yield from self._plot_args(this, kwargs)
#     394
#     395
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _plot_args(self, tup, kwargs)
#     368             x, y = index_of(tup[-1])
#     369
# --> 370         x, y = self._xy_from_xy(x, y)
#     371
#     372         if self.command == 'plot':
#
# ~/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_base.py in _xy_from_xy(self, x, y)
#     229         if x.shape[0] != y.shape[0]:
#     230             raise ValueError("x and y must have same first dimension, but "
# --> 231                              "have shapes {} and {}".format(x.shape, y.shape))
#     232         if x.ndim > 2 or y.ndim > 2:
#     233             raise ValueError("x and y can be no greater than 2-D, but have "
#
# ValueError: x and y must have same first dimension, but have shapes (1166,) and (1167,)
